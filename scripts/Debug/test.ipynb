# %%
import pandas as pd

path = "~/Desktop/VSCode/CIRAD_PhD_Robin/Data/Regression/Beef_Marbling_RandomSplit/"

for name in ["Ycal", "Yval"]:
    df = pd.read_csv(path + f"{name}.csv")       # lit la version séparée par virgules
    df = df.iloc[:, [0]]                 # garde UNIQUEMENT la première colonne
    df.to_csv(path + f"{name}.csv", sep=" ", index=False, header=True)

display(df)
# Out:
#      Marbling (MSA score)
# 0                     100
# 1                     100
# 2                     110
# 3                     120
# 4                     120
# ..                    ...
# 273                   540
# 274                   550
# 275                   600
# 276                   685
# 277                   770
#
# [278 rows x 1 columns]
