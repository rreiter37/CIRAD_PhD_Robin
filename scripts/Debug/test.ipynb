# %%
import pyarrow.parquet as pq
import polars as pl

meta = pq.read_table("/home/robinr/Desktop/VSCode/CIRAD_PhD_Robin/workspace/alpine_n_552_ks.meta.parquet").to_pandas()
display(meta.head())
display(meta.columns)

df = pl.read_parquet("/home/robinr/Desktop/VSCode/CIRAD_PhD_Robin/workspace/alpine_n_552_ks.meta.parquet")
print(df.columns)
print(df.head())
# Out:
#                  id     dataset_name     dataset_path       config_name  \
# 0  0d3b6c834ef9fcb4  alpine_n_552_ks  alpine_n_552_ks  0001_SOTA_c52e86
# 1  8f075c271028a402  alpine_n_552_ks  alpine_n_552_ks  0001_SOTA_c52e86
# 2  fe862fe6483236df  alpine_n_552_ks  alpine_n_552_ks  0001_SOTA_c52e86
# 3  baed44e9dcb0a7de  alpine_n_552_ks  alpine_n_552_ks  0001_SOTA_c52e86
# 4  8f6cb13fdb35e81f  alpine_n_552_ks  alpine_n_552_ks  0001_SOTA_c52e86
#
#                         config_path      pipeline_uid  step_idx  op_counter  \
# 0  alpine_n_552_ks/0001_SOTA_c52e86  0001_SOTA_c52e86        10           1
# 1  alpine_n_552_ks/0001_SOTA_c52e86  0001_SOTA_c52e86        10           1
# 2  alpine_n_552_ks/0001_SOTA_c52e86  0001_SOTA_c52e86        10           1
# 3  alpine_n_552_ks/0001_SOTA_c52e86  0001_SOTA_c52e86        10           2
# 4  alpine_n_552_ks/0001_SOTA_c52e86  0001_SOTA_c52e86        10           2
#
# ...
